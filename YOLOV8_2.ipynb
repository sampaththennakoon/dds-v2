# %%
# !nvidia-smi
# Out:
# Sat Apr  8 07:33:14 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   52C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pwd
# Out:
# '/content'

# %%
cd /content/drive/MyDrive/YOLOV8_2
# Out:
# /content/drive/MyDrive/YOLOV8_2

# %%
cd /content
# Out:
# /content

# %%
ls
# Out:
# drive/  sample_data/

# %%
cd data
# Out:
# /content/drive/MyDrive/YOLOV8/data

# %%
ls
# Out:
# test/  train/  val/

# %%
# !tar -xvf "USE_FINAL.tar.gz"
# Out:
# Streaming output truncated to the last 5000 lines.
# USE_FINAL/train/images/136b.jpg
# USE_FINAL/test/labels/596b.txt
# USE_FINAL/train/images/331.jpg
# USE_FINAL/train/images/334b.jpg
# USE_FINAL/test/labels/42.txt
# USE_FINAL/test/labels/597c.txt
# USE_FINAL/train/labels/175a.txt
# USE_FINAL/test/images/140a.jpg
# USE_FINAL/train/labels/339a.txt
# USE_FINAL/train/labels/304b.txt
# USE_FINAL/train/images/860a.jpg
# USE_FINAL/train/images/353.jpg
# USE_FINAL/train/labels/67.txt
# USE_FINAL/train/labels/502b.txt
# USE_FINAL/train/images/704.jpg
# USE_FINAL/train/images/861b.jpg
# USE_FINAL/train/images/364.jpg
# USE_FINAL/train/labels/78.txt
# USE_FINAL/train/images/737.jpg
# USE_FINAL/train/images/152a.jpg
# USE_FINAL/test/images/340c.jpg
# USE_FINAL/train/labels/504d.txt
# USE_FINAL/train/images/726.jpg
# USE_FINAL/train/images/863d.jpg
# USE_FINAL/train/images/386.jpg
# USE_FINAL/train/labels/505e.txt
# USE_FINAL/train/images/153b.jpg
# USE_FINAL/test/images/259.jpg
# ...

# %%
cd /content/
# Out:
# /content

# %%
pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.1/510.1 KB 11.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 23.8 MB/s eta 0:00:00
# ...

# %%
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.70 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.3/78.2 GB disk)

# %%
cd /content/drive/MyDrive/YOLOV8_2
# Out:
# /content/drive/MyDrive/YOLOV8_2

# %%
ls
# Out:
# data.yaml  USE_FINAL/  USE_FINAL.tar.gz  YOLOV8_2.ipynb

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=data.yaml epochs=200 imgsz=640 plots=True batch=32
# Out:
# Ultralytics YOLOv8.0.70 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=predict model='/content/drive/MyDrive/YOLOV8_2/runs/detect/train2/weights/best.pt' conf=0.6 source='/content/drive/MyDrive/YOLOV8_2/USE_FINAL/test/images' save=True save_txt=True
# Out:
# 2023-04-08 09:52:40.457198: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-08 09:52:41.782887: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.70 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11129841 parameters, 0 gradients, 28.5 GFLOPs
#
# image 1/788 /content/drive/MyDrive/YOLOV8_2/USE_FINAL/test/images/120.jpg: 384x640 1 SA, 1 BL, 61.4ms
# image 2/788 /content/drive/MyDrive/YOLOV8_2/USE_FINAL/test/images/120a.jpg: 384x640 1 SA, 1 BL, 11.1ms
# image 3/788 /content/drive/MyDrive/YOLOV8_2/USE_FINAL/test/images/120b.jpg: 384x640 1 BL, 11.1ms
# ...

# %%
# !ls runs/detect/train2
# Out:
# args.yaml					    train_batch1.jpg
# confusion_matrix.png				    train_batch2.jpg
# events.out.tfevents.1680291190.5828f5ceb972.5302.0  train_batch5310.jpg
# F1_curve.png					    train_batch5311.jpg
# labels_correlogram.jpg				    train_batch5312.jpg
# labels.jpg					    val_batch0_labels.jpg
# P_curve.png					    val_batch0_pred.jpg
# PR_curve.png					    val_batch1_labels.jpg
# R_curve.png					    val_batch1_pred.jpg
# results.csv					    val_batch2_labels.jpg
# results.png					    val_batch2_pred.jpg
# train_batch0.jpg				    weights

# %%
# !pip install Image
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 52.4 MB/s eta 0:00:00
# ...
#   Created wheel for Image: filename=image-1.5.33-py2.py3-none-any.whl size=19497 sha256=e35788cf6eb0d1c1621321cfed62cfd85830cc7e5681b200a12ad8beaa49017b
#   Stored in directory: /root/.cache/pip/wheels/14/4c/7c/d9b5c35a149d3bc8c72c7e92372913ff7dac9c6bd94bd1b8c9
# Successfully built Image
# ...

# %%
from PIL import Image

# %%
from PIL import Image
image0=Image.open('/content/drive/MyDrive/YOLOV8_2/runs/detect/train2/results.png')
image0
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2400x1200 at 0x7FE79872F460>

# %%
cd /content/drive/MyDrive/YOLOV8_2/runs/detect/train2/weights
# Out:
# /content/drive/MyDrive/YOLOV8/runs/detect/train4/weights

# %%
pip install onnx
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install onnx-tf
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.1/226.1 KB 2.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 24.8 MB/s eta 0:00:00
# ...

# %%
from onnx_tf.backend import prepare
# Out:
# /usr/local/lib/python3.9/dist-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.9.0 and strictly below 2.12.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.12.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
cd /content/drive/MyDrive/YOLOV8/runs/detect/train4/weights
# Out:
# /content/drive/MyDrive/YOLOV8/runs/detect/train4/weights

# %%
from ultralytics import YOLO

# %%
model = YOLO("best.pt")  # load a pretrained model (recommended for training)

# %%
success = model.export(format="onnx")  # export the model to ONNX format
# Out:
# Ultralytics YOLOv8.0.59 🚀 Python-3.9.16 torch-1.13.1+cu116 CPU
# Model summary (fused): 168 layers, 11129841 parameters, 0 gradients, 28.5 GFLOPs
#
# PyTorch: starting from best.pt with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 15, 8400) (21.4 MB)
#
# ONNX: starting export with onnx 1.13.1...
# ONNX: export success ✅ 1.8s, saved as best.onnx (42.7 MB)
#
# Export complete (4.7s)
# Results saved to /content/drive/MyDrive/YOLOV8/runs/detect/train4/weights
# Predict:         yolo predict task=detect model=best.onnx imgsz=640
# Validate:        yolo val task=detect model=best.onnx imgsz=640 data=data.yaml
# Visualize:       https://netron.app

# %%
success = model.export(format="pb")  # export the model to ONNX format
# Out:
# Ultralytics YOLOv8.0.59 🚀 Python-3.9.16 torch-1.13.1+cu116 CPU
# Model summary (fused): 168 layers, 11129841 parameters, 0 gradients, 28.5 GFLOPs
#
# PyTorch: starting from best.pt with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 15, 8400) (21.4 MB)
# requirements: YOLOv8 requirements "onnx" "onnx2tf>=1.7.7" "sng4onnx>=1.0.1" "onnxsim>=0.4.17" "onnx_graphsurgeon>=0.3.26" "tflite_support" "onnxruntime" not found, attempting AutoUpdate...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/, https://pypi.ngc.nvidia.com
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 59.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 334.3/334.3 KB 30.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 77.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.0/41.0 KB 4.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 MB 14.5 MB/s eta 0:00:00
# ...

# %%
import onnx
model = onnx.load('best.onnx')

# %%
from onnx_tf.backend import prepare
tf_rep = prepare(model)

# %%
tf_rep.export_graph('saved_model')
# Out:
# WARNING:absl:Found untraced functions such as gen_tensor_dict while saving (showing 1 of 1). These functions will not be directly callable after loading.

# %%
ls
# Out:
# best.onnx  best.pt  last.pt  saved_model/

# %%
cd saved_model
# Out:
# /content/drive/MyDrive/YOLOV8/runs/detect/train4/weights/saved_model

# %%
ls
# Out:
# best.onnx  best.pb  best.pt  best_saved_model/  last.pt  saved_model/

# %%
pip install -U tf2onnx
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 451.2/451.2 KB 24.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 71.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 23.3.3
#     Uninstalling flatbuffers-23.3.3:
#       Successfully uninstalled flatbuffers-23.3.3
# ...

# %%
import tf2onnx as tf2onnx

# %%
# !python -m tf2onnx.convert --saved-model saved_model --output_frozen_graph saved_model/frozen_inference_graph.pb
# Out:
# /usr/lib/python3.9/runpy.py:127: RuntimeWarning: 'tf2onnx.convert' found in sys.modules after import of package 'tf2onnx', but prior to execution of 'tf2onnx.convert'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# 2023-04-01 07:32:45,772 - WARNING - '--tag' not specified for saved_model. Using --tag serve
# 2023-04-01 07:32:46,547 - INFO - Signatures found in model: [serving_default].
# 2023-04-01 07:32:46,547 - WARNING - '--signature_def' not specified, using first signature: serving_default
# 2023-04-01 07:32:46,548 - INFO - Output names: ['output0']
# 2023-04-01 07:32:49,918 - INFO - Using tensorflow=2.12.0, onnx=1.13.1, tf2onnx=1.14.0/8f8d49
# 2023-04-01 07:32:49,919 - INFO - Using opset <onnx, 15>
# 2023-04-01 07:32:50,176 - INFO - Computed 0 values for constant folding
# 2023-04-01 07:32:50,177 - INFO - Computed 0 values for constant folding
# 2023-04-01 07:32:50,395 - INFO - Computed 9 values for constant folding
# ...

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2
import numpy as np

# %%
#path of the directory where you want to save your model
frozen_out_path = 'saved_model'
# name of the .pb file
frozen_graph_filename = 'frozen_graph_hope'
model = 'saved_model.pb'

# %%
from ultralytics import YOLO

# %%
model = YOLO("best.pt")

# %%
from PIL import Image
image0=Image.open('/content/drive/MyDrive/YOLOV8_2/runs/detect/predict/190.jpg')
image0
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x360 at 0x7FE6C139D310>

# %%
from PIL import Image
image0=Image.open('/content/drive/MyDrive/YOLOV8_2/runs/detect/predict/222.jpg')
image0
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x360 at 0x7FE6C90E8A90>

# %%
len(result.boxes)
# Out:
# 3

# %%
result.boxes.xyxy
# Out:
# tensor([[292.4913, 286.6138, 323.4183, 319.3201],
#         [430.3620, 284.6022, 501.9800, 309.5924],
#         [529.6185, 276.8619, 618.5988, 289.4835]])

# %%
result.boxes.conf
# Out:
# tensor([0.9482, 0.9292, 0.8760])

# %%
result.boxes.cls
# Out:
# tensor([10.,  9.,  0.])

# %%
len_results = len(result.boxes)
result_list_json = [
        {
            'class_id': int(result.boxes.cls[idx]),
            'class': result.names[int(result.boxes.cls[idx])],
            'confidence': float(result.boxes.conf[idx]),
            'bbox': {
                'x_min': int(result.boxes.boxes[idx][0]),
                'y_min': int(result.boxes.boxes[idx][1]),
                'x_max': int(result.boxes.boxes[idx][2]),
                'y_max': int(result.boxes.boxes[idx][3]),
            },
        } for idx in range(len_results)
    ]
result_list_json
# Out:
# [{'class_id': 10,
#   'class': 'LA',
#   'confidence': 0.9482210278511047,
#   'bbox': {'x_min': 292, 'y_min': 286, 'x_max': 323, 'y_max': 319}},
#  {'class_id': 9,
#   'class': 'SLA',
#   'confidence': 0.9291789531707764,
#   'bbox': {'x_min': 430, 'y_min': 284, 'x_max': 501, 'y_max': 309}},
#  {'class_id': 0,
#   'class': 'SA',
#   'confidence': 0.8760370016098022,
#   'bbox': {'x_min': 529, 'y_min': 276, 'x_max': 618, 'y_max': 289}}]

# %%
result.boxes.cls.cpu().numpy()
# Out:
# array([         10,           9,           0], dtype=float32)

# %%
cls = result.boxes.cls.cpu().numpy()

# %%
pip install ultralyticsplus
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
